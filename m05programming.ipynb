# %%
#Testing your Code
assert sum([1, 2, 1]) == 6, "Should be 6"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 assert sum([1, 2, 1]) == 6, "Should be 6"
#
# AssertionError: Should be 6

# %%
def test_sum():
    assert sum([1, 2, 3]) == 6, "Should be 6"

def test_sum_tuple():
    assert sum((1, 2, 2)) == 6, "Should be 6"

if __name__ == "__main__":
    test_sum()
    test_sum_tuple()
    print("Everything passed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 9
#       7 if __name__ == "__main__":
#       8     test_sum()
# ----> 9     test_sum_tuple()
#      10     print("Everything passed")
#
# Cell In[9], line 5, in test_sum_tuple()
#       4 def test_sum_tuple():
# ----> 5     assert sum((1, 2, 2)) == 6, "Should be 6"
#
# AssertionError: Should be 6

# %%
#Other sections completed on VS Code
#File outputs with an error if an assertion isn't true
#The results of the test also commented on the VS Code portion
